# %%
import matplotlib.pyplot as plt
import json
from IPython.display import Image

# %%
X = [25, 50, 100, 200, 400]

# %% [markdown]
# # LOTZ

# %%
Y = [3494, 13480, 52999, 223346]
Yfixed = [5419, 23518, 96294, 382704] #Averages of 100 experiments
Yfixedv2 = [6103, 28579, 124061, 555993] #Avgs of 100 experiments
fig = plt.figure(figsize=(10,10))
plt.plot(X[0:len(Y)], Y, marker="o", label="NSGA-II (bug)")
plt.plot(X[0:len(Yfixed)], Yfixed, marker="o", color="black", label="NSGA-II")
plt.plot(X[0:len(Yfixedv2)], Yfixedv2, marker="o", color="red", label="NSGA-II v2")
plt.yscale('log')
plt.xscale('log')
plt.xticks(X[0:len(Y)], ["25", "50", "100", "200"])
plt.grid()
plt.ylim(10**2, 10**7)
plt.legend()

# %%
Image(filename='LOTZ.png')

# %% [markdown]
# # ZeroMaxOneMax

# %%
Y = [867, 2249, 5517, 12807, 28690]
Yfixed = [2434, 7786, 20414, 50987, 128479] #Avgs of 100 experiments
Yfixedv2 = [2686, 10250, 28840, 77437, 197099] #Avgs of 100 experiments
fig = plt.figure(figsize=(10,10))
plt.plot(X[0:len(Y)], Y, marker="o", label="NSGA-II (bug)")
plt.plot(X[0:len(Yfixed)], Yfixed, marker="o", color="black", label="NSGA-II")
plt.plot(X[0:len(Yfixedv2)], Yfixedv2, marker="o", color="red", label="NSGA-II v2")
plt.yscale('log')
plt.xscale('log')
plt.xticks(X[0:len(Y)], ["25", "50", "100", "200", "400"])
plt.grid()
plt.ylim(10**2, 10**7)
plt.legend()

# %%
Image(filename='ZMOM.png')
